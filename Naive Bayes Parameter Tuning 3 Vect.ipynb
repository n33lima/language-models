# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import datetime,time
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV,SGDClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer,TfidfTransformer, HashingVectorizer
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sklearn.svm import SVC
import math
import statistics
from collections import defaultdict
from imblearn import over_sampling
from imblearn.over_sampling import SVMSMOTE
import re

# %%
data=pd.read_csv('data/train.csv')
X = data['text']
y = data['target']


# different Vectorizers
def Hash_vec(X):
    Hvect=HashingVectorizer(lowercase=True,ngram_range=(1,1))
    X=Hvect.fit_transform(X)
    
    return X

def Count_Vec(X):
    CountV=CountVectorizer(lowercase=True)
    X=CountV.fit_transform(X)
    
    return X

def TFIDF_vec(X):
    tfidf=TfidfVectorizer(use_idf=True,lowercase=True)
    X=tfidf.fit_transform(X)
    
    return X


def overSample(X,y):
    
    oversample = SVMSMOTE(n_jobs=-1,random_state=47)
    X, y = oversample.fit_resample(X, y)
    
    return X,y



# ML methods
NB1 = BernoulliNB(alpha=0.0)
NB2 = BernoulliNB(alpha=0.1)
NB3 = BernoulliNB(alpha=0.2)
NB4 = BernoulliNB(alpha=0.3)
NB5 = BernoulliNB(alpha=0.4)
NB6 = BernoulliNB(alpha=0.5)
NB7 = BernoulliNB(alpha=0.6)
NB8 = BernoulliNB(alpha=0.7)
NB9 = BernoulliNB(alpha=0.8)
NB10 = BernoulliNB(alpha=0.9)
NB11 = BernoulliNB(alpha=1.0)
          
list_of_Vectorizers = {'Hashing Vectorizer':Hash_vec,'Count Vectorizer':Count_Vec,
                       'TFIDF Vectorizer':TFIDF_vec}

list_of_models = {'Bernoulli Naive Bayes classifier with 0 Laplace Smoothing':NB1,
                  'Bernoulli Naive Bayes classifier with 0.1 Laplace Smoothing':NB2, 
                  'Bernoulli Naive Bayes classifier with 0.2 Laplace Smoothing':NB3, 
                  'Bernoulli Naive Bayes classifier with 0.3 Laplace Smoothing':NB4, 
                  'Bernoulli Naive Bayes classifier with 0.4 Laplace Smoothing':NB5,
                  'Bernoulli Naive Bayes classifier with 0.5 Laplace Smoothing':NB6,
                  'Bernoulli Naive Bayes classifier with 0.6 Laplace Smoothing':NB7, 
                  'Bernoulli Naive Bayes classifier with 0.7 Laplace Smoothing':NB8, 
                  'Bernoulli Naive Bayes classifier with 0.8 Laplace Smoothing':NB9, 
                  'Bernoulli Naive Bayes classifier with 0.9 Laplace Smoothing':NB10,
                  'Bernoulli Naive Bayes classifier with 1 Laplace Smoothing':NB11}


models_accuracy = defaultdict()
models_built_time=defaultdict()
models_prediction_time=defaultdict()



def get_Model_results(models,vectorizers,X,y):
    
    for Vectorizer_name, vectorizer in vectorizers.items():
        print('\n...........Results for {}..........'.format(Vectorizer_name))
        X_vec=vectorizer(X)
        X_samp,y_samp=overSample(X_vec,y)

        X_train, X_test, y_train, y_test = train_test_split(X_samp, y_samp, test_size=0.30, random_state=42)
        
        for model_name, model in models.items():
            start_time =  time.time()%60
            text_clf = model.fit(X_train, y_train)
            end_time= time.time()%60

            if(end_time>start_time):
                time_to_build_the_model='%.2f' %(end_time-start_time)
            else:
                time_to_build_the_model='%.2f' %(start_time-end_time)


            start_time = time.time()%60
            predicted = text_clf.predict(X_test)
            end_time= time.time()%60

            if(end_time>start_time):
                time_to_predict='%.2f' %(end_time-start_time)
            else:
                time_to_predict='%.2f' %(start_time-end_time)


            print('\n-----------------\nModel: {}'.format(model_name))
            print(confusion_matrix(y_test,predicted))
            print(classification_report(y_test,predicted))
            print('\nAccuracy on Training:\n{00:.2f} %'.format(text_clf.score(X_train,y_train)*100))

            print('\nAccuracy on Testing:\n{00:.2f} %'.format(accuracy_score(y_test,predicted)*100))

            print('\nTime taken to build the model is {} Seconds'.format(time_to_build_the_model))
            print('\nTime taken for prediction is {} Seconds'.format(time_to_predict))



get_Model_results(list_of_models,list_of_Vectorizers,X,y)
# Out:
# ...........Results for Hashing Vectorizer..........
# C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:508: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn('alpha too small will result in numeric errors, '
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0 Laplace Smoothing
# [[1083  228]
#  [ 304  991]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80      1311
#            1       0.81      0.77      0.79      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 95.38 %
#
# Accuracy on Testing:
# 79.59 %
#
# Time taken to build the model is 0.09 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.1 Laplace Smoothing
# [[1109  202]
#  [ 305  990]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      1311
#            1       0.83      0.76      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.81      0.81      0.81      2606
# weighted avg       0.81      0.81      0.81      2606
#
#
# Accuracy on Training:
# 93.22 %
#
# Accuracy on Testing:
# 80.54 %
#
# Time taken to build the model is 0.13 Seconds
#
# Time taken for prediction is 0.13 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.2 Laplace Smoothing
# [[1100  211]
#  [ 297  998]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      1311
#            1       0.83      0.77      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.81      0.80      0.80      2606
# weighted avg       0.81      0.81      0.80      2606
#
#
# Accuracy on Training:
# 92.38 %
#
# Accuracy on Testing:
# 80.51 %
#
# Time taken to build the model is 0.07 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.3 Laplace Smoothing
# [[1085  226]
#  [ 290 1005]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      1311
#            1       0.82      0.78      0.80      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 91.66 %
#
# Accuracy on Testing:
# 80.20 %
#
# Time taken to build the model is 0.13 Seconds
#
# Time taken for prediction is 0.17 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.4 Laplace Smoothing
# [[1077  234]
#  [ 284 1011]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81      1311
#            1       0.81      0.78      0.80      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 91.16 %
#
# Accuracy on Testing:
# 80.12 %
#
# Time taken to build the model is 0.08 Seconds
#
# Time taken for prediction is 0.13 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.5 Laplace Smoothing
# [[1055  256]
#  [ 273 1022]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80      1311
#            1       0.80      0.79      0.79      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 90.80 %
#
# Accuracy on Testing:
# 79.70 %
#
# Time taken to build the model is 0.08 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.6 Laplace Smoothing
# [[1037  274]
#  [ 258 1037]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80      1311
#            1       0.79      0.80      0.80      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 90.44 %
#
# Accuracy on Testing:
# 79.59 %
#
# Time taken to build the model is 0.09 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.7 Laplace Smoothing
# [[1010  301]
#  [ 242 1053]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      1311
#            1       0.78      0.81      0.80      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.79      0.79      0.79      2606
# weighted avg       0.79      0.79      0.79      2606
#
#
# Accuracy on Training:
# 89.75 %
#
# Accuracy on Testing:
# 79.16 %
#
# Time taken to build the model is 0.09 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.8 Laplace Smoothing
# [[ 976  335]
#  [ 229 1066]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.78      1311
#            1       0.76      0.82      0.79      1295
#
#     accuracy                           0.78      2606
#    macro avg       0.79      0.78      0.78      2606
# weighted avg       0.79      0.78      0.78      2606
#
#
# Accuracy on Training:
# 89.12 %
#
# Accuracy on Testing:
# 78.36 %
#
# Time taken to build the model is 0.10 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.9 Laplace Smoothing
# [[ 948  363]
#  [ 215 1080]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77      1311
#            1       0.75      0.83      0.79      1295
#
#     accuracy                           0.78      2606
#    macro avg       0.78      0.78      0.78      2606
# weighted avg       0.78      0.78      0.78      2606
#
#
# Accuracy on Training:
# 88.38 %
#
# Accuracy on Testing:
# 77.82 %
#
# Time taken to build the model is 0.08 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 1 Laplace Smoothing
# [[ 913  398]
#  [ 206 1089]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.75      1311
#            1       0.73      0.84      0.78      1295
#
#     accuracy                           0.77      2606
#    macro avg       0.77      0.77      0.77      2606
# weighted avg       0.77      0.77      0.77      2606
#
#
# Accuracy on Training:
# 87.43 %
#
# Accuracy on Testing:
# 76.82 %
#
# Time taken to build the model is 0.09 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# ...........Results for Count Vectorizer..........
# C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:508: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn('alpha too small will result in numeric errors, '
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0 Laplace Smoothing
# [[1071  240]
#  [ 338  957]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79      1311
#            1       0.80      0.74      0.77      1295
#
#     accuracy                           0.78      2606
#    macro avg       0.78      0.78      0.78      2606
# weighted avg       0.78      0.78      0.78      2606
#
#
# Accuracy on Training:
# 97.25 %
#
# Accuracy on Testing:
# 77.82 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.1 Laplace Smoothing
# [[1145  166]
#  [ 322  973]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      1311
#            1       0.85      0.75      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 93.73 %
#
# Accuracy on Testing:
# 81.27 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.01 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.2 Laplace Smoothing
# [[1146  165]
#  [ 320  975]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.83      1311
#            1       0.86      0.75      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 92.78 %
#
# Accuracy on Testing:
# 81.39 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.3 Laplace Smoothing
# [[1147  164]
#  [ 321  974]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.83      1311
#            1       0.86      0.75      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 91.92 %
#
# Accuracy on Testing:
# 81.39 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.4 Laplace Smoothing
# [[1145  166]
#  [ 317  978]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.83      1311
#            1       0.85      0.76      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 91.33 %
#
# Accuracy on Testing:
# 81.47 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.5 Laplace Smoothing
# [[1144  167]
#  [ 322  973]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      1311
#            1       0.85      0.75      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 90.70 %
#
# Accuracy on Testing:
# 81.24 %
#
# Time taken to build the model is 0.02 Seconds
#
# Time taken for prediction is 0.01 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.6 Laplace Smoothing
# [[1139  172]
#  [ 319  976]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      1311
#            1       0.85      0.75      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 90.39 %
#
# Accuracy on Testing:
# 81.16 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.7 Laplace Smoothing
# [[1140  171]
#  [ 316  979]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      1311
#            1       0.85      0.76      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 90.08 %
#
# Accuracy on Testing:
# 81.31 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.8 Laplace Smoothing
# [[1136  175]
#  [ 315  980]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      1311
#            1       0.85      0.76      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 89.82 %
#
# Accuracy on Testing:
# 81.20 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.9 Laplace Smoothing
# [[1134  177]
#  [ 313  982]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      1311
#            1       0.85      0.76      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 89.47 %
#
# Accuracy on Testing:
# 81.20 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 1 Laplace Smoothing
# [[1134  177]
#  [ 313  982]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      1311
#            1       0.85      0.76      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 89.32 %
#
# Accuracy on Testing:
# 81.20 %
#
# Time taken to build the model is 0.02 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# ...........Results for TFIDF Vectorizer..........
# C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:508: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn('alpha too small will result in numeric errors, '
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0 Laplace Smoothing
# [[1072  239]
#  [ 242 1053]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      1311
#            1       0.82      0.81      0.81      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.82      0.82      2606
# weighted avg       0.82      0.82      0.82      2606
#
#
# Accuracy on Training:
# 98.68 %
#
# Accuracy on Testing:
# 81.54 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.1 Laplace Smoothing
# [[1137  174]
#  [ 256 1039]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84      1311
#            1       0.86      0.80      0.83      1295
#
#     accuracy                           0.83      2606
#    macro avg       0.84      0.83      0.83      2606
# weighted avg       0.84      0.83      0.83      2606
#
#
# Accuracy on Training:
# 95.87 %
#
# Accuracy on Testing:
# 83.50 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.2 Laplace Smoothing
# [[1150  161]
#  [ 261 1034]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.84      1311
#            1       0.87      0.80      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 94.88 %
#
# Accuracy on Testing:
# 83.81 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.3 Laplace Smoothing
# [[1153  158]
#  [ 265 1030]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84      1311
#            1       0.87      0.80      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 94.19 %
#
# Accuracy on Testing:
# 83.77 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.4 Laplace Smoothing
# [[1157  154]
#  [ 271 1024]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84      1311
#            1       0.87      0.79      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 93.62 %
#
# Accuracy on Testing:
# 83.69 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.5 Laplace Smoothing
# [[1164  147]
#  [ 273 1022]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1311
#            1       0.87      0.79      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 93.02 %
#
# Accuracy on Testing:
# 83.88 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.6 Laplace Smoothing
# [[1164  147]
#  [ 273 1022]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1311
#            1       0.87      0.79      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 92.43 %
#
# Accuracy on Testing:
# 83.88 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.7 Laplace Smoothing
# [[1165  146]
#  [ 273 1022]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1311
#            1       0.88      0.79      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 92.00 %
#
# Accuracy on Testing:
# 83.92 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.01 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.8 Laplace Smoothing
# [[1164  147]
#  [ 278 1017]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1311
#            1       0.87      0.79      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 91.63 %
#
# Accuracy on Testing:
# 83.69 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 0.9 Laplace Smoothing
# [[1167  144]
#  [ 278 1017]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1311
#            1       0.88      0.79      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 91.33 %
#
# Accuracy on Testing:
# 83.81 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
#
# -----------------
# Model: Bernoulli Naive Bayes classifier with 1 Laplace Smoothing
# [[1168  143]
#  [ 281 1014]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1311
#            1       0.88      0.78      0.83      1295
#
#     accuracy                           0.84      2606
#    macro avg       0.84      0.84      0.84      2606
# weighted avg       0.84      0.84      0.84      2606
#
#
# Accuracy on Training:
# 91.18 %
#
# Accuracy on Testing:
# 83.73 %
#
# Time taken to build the model is 0.01 Seconds
#
# Time taken for prediction is 0.00 Seconds
