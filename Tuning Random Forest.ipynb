# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import datetime,time
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer,TfidfTransformer, HashingVectorizer
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sklearn.svm import SVC
import math
import statistics
from collections import defaultdict
from imblearn import over_sampling
from imblearn.over_sampling import SVMSMOTE
import re

# %%
data=pd.read_csv('/Users/joe/Desktop/language-models-sprint1/data/train.csv')
X = data['text']
y = data['target']


# different Vectorizers
def Hash_vec(X):
    Hvect=HashingVectorizer(lowercase=True,ngram_range=(1,1))
    X=Hvect.fit_transform(X)
    
    return X

def Count_Vec(X):
    CountV=CountVectorizer(lowercase=True)
    X=CountV.fit_transform(X)
    
    return X

def TFIDF_vec(X):
    tfidf=TfidfVectorizer(use_idf=True,lowercase=True)
    X=tfidf.fit_transform(X)
    
    return X


def overSample(X,y):
    
    oversample = SVMSMOTE(n_jobs=-1,random_state=47)
    X, y = oversample.fit_resample(X, y)
    
    return X,y



# Random Forest starting from 100 tree to 400 trees
RF100=RandomForestClassifier(n_estimators=100,n_jobs=-1,max_depth=100)
RF110=RandomForestClassifier(n_estimators=110,n_jobs=-1,max_depth=100)
RF120=RandomForestClassifier(n_estimators=120,n_jobs=-1,max_depth=100)
RF130=RandomForestClassifier(n_estimators=130,n_jobs=-1,max_depth=100)
RF140=RandomForestClassifier(n_estimators=140,n_jobs=-1,max_depth=100)
RF150=RandomForestClassifier(n_estimators=150,n_jobs=-1,max_depth=100)
RF160=RandomForestClassifier(n_estimators=160,n_jobs=-1,max_depth=100)
RF170=RandomForestClassifier(n_estimators=170,n_jobs=-1,max_depth=100)
RF180=RandomForestClassifier(n_estimators=180,n_jobs=-1,max_depth=100)
RF190=RandomForestClassifier(n_estimators=190,n_jobs=-1,max_depth=100)
RF200=RandomForestClassifier(n_estimators=200,n_jobs=-1,max_depth=100)


RF210=RandomForestClassifier(n_estimators=210,n_jobs=-1,max_depth=100)
RF220=RandomForestClassifier(n_estimators=220,n_jobs=-1,max_depth=100)
RF230=RandomForestClassifier(n_estimators=230,n_jobs=-1,max_depth=100)
RF240=RandomForestClassifier(n_estimators=240,n_jobs=-1,max_depth=100)
RF250=RandomForestClassifier(n_estimators=250,n_jobs=-1,max_depth=100)
RF260=RandomForestClassifier(n_estimators=260,n_jobs=-1,max_depth=100)
RF270=RandomForestClassifier(n_estimators=270,n_jobs=-1,max_depth=100)
RF280=RandomForestClassifier(n_estimators=280,n_jobs=-1,max_depth=100)
RF290=RandomForestClassifier(n_estimators=290,n_jobs=-1,max_depth=100)
RF300=RandomForestClassifier(n_estimators=300,n_jobs=-1,max_depth=100)
                      
RF310=RandomForestClassifier(n_estimators=310,n_jobs=-1,max_depth=100)
RF320=RandomForestClassifier(n_estimators=320,n_jobs=-1,max_depth=100)
RF330=RandomForestClassifier(n_estimators=330,n_jobs=-1,max_depth=100)
RF340=RandomForestClassifier(n_estimators=340,n_jobs=-1,max_depth=100)
RF350=RandomForestClassifier(n_estimators=350,n_jobs=-1,max_depth=100)
RF360=RandomForestClassifier(n_estimators=360,n_jobs=-1,max_depth=100)
RF370=RandomForestClassifier(n_estimators=370,n_jobs=-1,max_depth=100)
RF380=RandomForestClassifier(n_estimators=380,n_jobs=-1,max_depth=100)
RF390=RandomForestClassifier(n_estimators=390,n_jobs=-1,max_depth=100)
RF400=RandomForestClassifier(n_estimators=400,n_jobs=-1,max_depth=100)



list_of_Vectorizers = {'Hashing Vectorizer':Hash_vec,'Count Vectorizer':Count_Vec,
                       'TFIDF Vectorizer':TFIDF_vec}



list_of_models = {'Random Forest100':RF100,'Random Forest110':RF110,'Random Forest120':RF120,'Random Forest130':RF130,
                 'Random Forest140':RF140,'Random Forest150':RF150,
                 'Random Forest160':RF160,'Random Forest170':RF170,'Random Forest180':RF180,'Random Forest190':RF190,
                 'Random Forest200':RF200,'Random Forest210':RF210,
                 'Random Forest220':RF220,'Random Forest230':RF230,'Random Forest240':RF240,'Random Forest250':RF250
                 ,'Random Forest260':RF260,'Random Forest270':RF270,'Random Forest280':RF280,
                 'Random Forest290':RF290,'Random Forest300':RF300,
                 'Random Forest310':RF310,'Random Forest320':RF320,'Random Forest330':RF330,
                 'Random Forest340':RF340,'Random Forest350':RF350,'Random Forest360':RF360,'Random Forest370':RF370,
                 'Random Forest380':RF380,'Random Forest390':RF390,'Random Forest400':RF400}

models_accuracy = defaultdict()
models_built_time=defaultdict()
models_prediction_time=defaultdict()



def get_Model_results(models,vectorizers,X,y):
    
    for Vectorizer_name, vectorizer in vectorizers.items():
        print('\n...........Results for {}..........'.format(Vectorizer_name))
        X_vec=vectorizer(X)
        X_samp,y_samp=overSample(X_vec,y)

        X_train, X_test, y_train, y_test = train_test_split(X_samp, y_samp, test_size=0.30, random_state=42)
        
        for model_name, model in models.items():
            start_time =  time.time()%60
            text_clf = model.fit(X_train, y_train)
            end_time= time.time()%60

            if(end_time>start_time):
                time_to_build_the_model='%.2f' %(end_time-start_time)
            else:
                time_to_build_the_model='%.2f' %(start_time-end_time)


            start_time = time.time()%60
            predicted = text_clf.predict(X_test)
            end_time= time.time()%60

            if(end_time>start_time):
                time_to_predict='%.2f' %(end_time-start_time)
            else:
                time_to_predict='%.2f' %(start_time-end_time)


            print('\n-----------------\nModel: {}'.format(model_name))
            print(confusion_matrix(y_test,predicted))
            print(classification_report(y_test,predicted))
            print('\nAccuracy on Training:\n{00:.2f} %'.format(text_clf.score(X_train,y_train)*100))

            print('\nAccuracy on Testing:\n{00:.2f} %'.format(accuracy_score(y_test,predicted)*100))

            print('\nTime taken to build the model is {} Seconds'.format(time_to_build_the_model))
            print('\nTime taken for prediction is {} Seconds'.format(time_to_predict))


get_Model_results(list_of_models,list_of_Vectorizers,X,y)
# Out:
# ...........Results for Hashing Vectorizer..........
#
# -----------------
# Model: Random Forest100
# [[1220   91]
#  [ 373  922]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1311
#            1       0.91      0.71      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.84      0.82      0.82      2606
# weighted avg       0.84      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.26 %
#
# Accuracy on Testing:
# 82.19 %
#
# Time taken to build the model is 20.98 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# -----------------
# Model: Random Forest110
# [[1162  149]
#  [ 367  928]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82      1311
#            1       0.86      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.81      0.80      0.80      2606
# weighted avg       0.81      0.80      0.80      2606
#
#
# Accuracy on Training:
# 94.95 %
#
# Accuracy on Testing:
# 80.20 %
#
# Time taken to build the model is 26.88 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest120
# [[1200  111]
#  [ 366  929]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.83      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.11 %
#
# Accuracy on Testing:
# 81.70 %
#
# Time taken to build the model is 21.97 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# -----------------
# Model: Random Forest130
# [[1205  106]
#  [ 361  934]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.23 %
#
# Accuracy on Testing:
# 82.08 %
#
# Time taken to build the model is 35.41 Seconds
#
# Time taken for prediction is 0.16 Seconds
#
# -----------------
# Model: Random Forest140
# [[1204  107]
#  [ 366  929]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.18 %
#
# Accuracy on Testing:
# 81.85 %
#
# Time taken to build the model is 21.34 Seconds
#
# Time taken for prediction is 0.15 Seconds
#
# -----------------
# Model: Random Forest150
# [[1199  112]
#  [ 350  945]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84      1311
#            1       0.89      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.77 %
#
# Accuracy on Testing:
# 82.27 %
#
# Time taken to build the model is 25.45 Seconds
#
# Time taken for prediction is 0.16 Seconds
#
# -----------------
# Model: Random Forest160
# [[1189  122]
#  [ 374  921]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83      1311
#            1       0.88      0.71      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.66 %
#
# Accuracy on Testing:
# 80.97 %
#
# Time taken to build the model is 37.57 Seconds
#
# Time taken for prediction is 0.16 Seconds
#
# -----------------
# Model: Random Forest170
# [[1192  119]
#  [ 367  928]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83      1311
#            1       0.89      0.72      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.83      0.81      0.81      2606
# weighted avg       0.83      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.51 %
#
# Accuracy on Testing:
# 81.35 %
#
# Time taken to build the model is 21.29 Seconds
#
# Time taken for prediction is 0.17 Seconds
#
# -----------------
# Model: Random Forest180
# [[1194  117]
#  [ 358  937]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 96.10 %
#
# Accuracy on Testing:
# 81.77 %
#
# Time taken to build the model is 17.61 Seconds
#
# Time taken for prediction is 0.18 Seconds
#
# -----------------
# Model: Random Forest190
# [[1199  112]
#  [ 356  939]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84      1311
#            1       0.89      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.39 %
#
# Accuracy on Testing:
# 82.04 %
#
# Time taken to build the model is 44.10 Seconds
#
# Time taken for prediction is 0.19 Seconds
#
# -----------------
# Model: Random Forest200
# [[1183  128]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.72      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.34 %
#
# Accuracy on Testing:
# 81.20 %
#
# Time taken to build the model is 14.28 Seconds
#
# Time taken for prediction is 0.22 Seconds
#
# -----------------
# Model: Random Forest210
# [[1203  108]
#  [ 361  934]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.38 %
#
# Accuracy on Testing:
# 82.00 %
#
# Time taken to build the model is 3.92 Seconds
#
# Time taken for prediction is 0.21 Seconds
#
# -----------------
# Model: Random Forest220
# [[1206  105]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.66 %
#
# Accuracy on Testing:
# 81.85 %
#
# Time taken to build the model is 1.19 Seconds
#
# Time taken for prediction is 0.22 Seconds
#
# -----------------
# Model: Random Forest230
# [[1201  110]
#  [ 360  935]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.77 %
#
# Accuracy on Testing:
# 81.96 %
#
# Time taken to build the model is 2.93 Seconds
#
# Time taken for prediction is 0.24 Seconds
#
# -----------------
# Model: Random Forest240
# [[1202  109]
#  [ 371  924]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83      1311
#            1       0.89      0.71      0.79      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.61 %
#
# Accuracy on Testing:
# 81.58 %
#
# Time taken to build the model is 11.95 Seconds
#
# Time taken for prediction is 0.26 Seconds
#
# -----------------
# Model: Random Forest250
# [[1194  117]
#  [ 358  937]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.46 %
#
# Accuracy on Testing:
# 81.77 %
#
# Time taken to build the model is 10.13 Seconds
#
# Time taken for prediction is 0.24 Seconds
#
# -----------------
# Model: Random Forest260
# [[1213   98]
#  [ 357  938]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1311
#            1       0.91      0.72      0.80      1295
#
#     accuracy                           0.83      2606
#    macro avg       0.84      0.82      0.82      2606
# weighted avg       0.84      0.83      0.82      2606
#
#
# Accuracy on Training:
# 96.05 %
#
# Accuracy on Testing:
# 82.54 %
#
# Time taken to build the model is 45.62 Seconds
#
# Time taken for prediction is 0.25 Seconds
#
# -----------------
# Model: Random Forest270
# [[1198  113]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1311
#            1       0.89      0.72      0.79      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.81      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.34 %
#
# Accuracy on Testing:
# 81.54 %
#
# Time taken to build the model is 14.46 Seconds
#
# Time taken for prediction is 0.31 Seconds
#
# -----------------
# Model: Random Forest280
# [[1201  110]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.83      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.57 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 20.39 Seconds
#
# Time taken for prediction is 0.33 Seconds
#
# -----------------
# Model: Random Forest290
# [[1208  103]
#  [ 371  924]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.71      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.57 %
#
# Accuracy on Testing:
# 81.81 %
#
# Time taken to build the model is 37.26 Seconds
#
# Time taken for prediction is 0.32 Seconds
#
# -----------------
# Model: Random Forest300
# [[1183  128]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.72      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.41 %
#
# Accuracy on Testing:
# 81.20 %
#
# Time taken to build the model is 21.35 Seconds
#
# Time taken for prediction is 0.29 Seconds
#
# -----------------
# Model: Random Forest310
# [[1199  112]
#  [ 361  934]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.56 %
#
# Accuracy on Testing:
# 81.85 %
#
# Time taken to build the model is 8.75 Seconds
#
# Time taken for prediction is 0.30 Seconds
#
# -----------------
# Model: Random Forest320
# [[1193  118]
#  [ 360  935]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1311
#            1       0.89      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.43 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 11.30 Seconds
#
# Time taken for prediction is 0.30 Seconds
#
# -----------------
# Model: Random Forest330
# [[1218   93]
#  [ 371  924]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1311
#            1       0.91      0.71      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.84      0.82      0.82      2606
# weighted avg       0.84      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.66 %
#
# Accuracy on Testing:
# 82.19 %
#
# Time taken to build the model is 46.20 Seconds
#
# Time taken for prediction is 0.34 Seconds
#
# -----------------
# Model: Random Forest340
# [[1203  108]
#  [ 358  937]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.33 %
#
# Accuracy on Testing:
# 82.12 %
#
# Time taken to build the model is 16.01 Seconds
#
# Time taken for prediction is 0.32 Seconds
#
# -----------------
# Model: Random Forest350
# [[1199  112]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1311
#            1       0.89      0.72      0.79      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.66 %
#
# Accuracy on Testing:
# 81.58 %
#
# Time taken to build the model is 20.51 Seconds
#
# Time taken for prediction is 0.34 Seconds
#
# -----------------
# Model: Random Forest360
# [[1203  108]
#  [ 356  939]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.72 %
#
# Accuracy on Testing:
# 82.19 %
#
# Time taken to build the model is 25.10 Seconds
#
# Time taken for prediction is 0.34 Seconds
#
# -----------------
# Model: Random Forest370
# [[1202  109]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.28 %
#
# Accuracy on Testing:
# 81.93 %
#
# Time taken to build the model is 34.94 Seconds
#
# Time taken for prediction is 0.35 Seconds
#
# -----------------
# Model: Random Forest380
# [[1188  123]
#  [ 357  938]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83      1311
#            1       0.88      0.72      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.48 %
#
# Accuracy on Testing:
# 81.58 %
#
# Time taken to build the model is 25.90 Seconds
#
# Time taken for prediction is 0.36 Seconds
#
# -----------------
# Model: Random Forest390
# [[1214   97]
#  [ 357  938]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1311
#            1       0.91      0.72      0.81      1295
#
#     accuracy                           0.83      2606
#    macro avg       0.84      0.83      0.82      2606
# weighted avg       0.84      0.83      0.82      2606
#
#
# Accuracy on Training:
# 95.94 %
#
# Accuracy on Testing:
# 82.58 %
#
# Time taken to build the model is 31.95 Seconds
#
# Time taken for prediction is 0.38 Seconds
#
# -----------------
# Model: Random Forest400
# [[1212   99]
#  [ 371  924]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1311
#            1       0.90      0.71      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.66 %
#
# Accuracy on Testing:
# 81.96 %
#
# Time taken to build the model is 26.90 Seconds
#
# Time taken for prediction is 0.37 Seconds
#
# ...........Results for Count Vectorizer..........
#
# -----------------
# Model: Random Forest100
# [[1137  174]
#  [ 369  926]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 94.92 %
#
# Accuracy on Testing:
# 79.16 %
#
# Time taken to build the model is 1.76 Seconds
#
# Time taken for prediction is 0.04 Seconds
#
# -----------------
# Model: Random Forest110
# [[1138  173]
#  [ 359  936]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.79      2606
# weighted avg       0.80      0.80      0.79      2606
#
#
# Accuracy on Training:
# 94.74 %
#
# Accuracy on Testing:
# 79.59 %
#
# Time taken to build the model is 1.95 Seconds
#
# Time taken for prediction is 0.04 Seconds
#
# -----------------
# Model: Random Forest120
# [[1148  163]
#  [ 365  930]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 95.23 %
#
# Accuracy on Testing:
# 79.74 %
#
# Time taken to build the model is 2.15 Seconds
#
# Time taken for prediction is 0.04 Seconds
#
# -----------------
# Model: Random Forest130
# [[1143  168]
#  [ 370  925]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.71      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.10 %
#
# Accuracy on Testing:
# 79.36 %
#
# Time taken to build the model is 2.40 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest140
# [[1138  173]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 94.83 %
#
# Accuracy on Testing:
# 79.24 %
#
# Time taken to build the model is 2.61 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest150
# [[1133  178]
#  [ 366  929]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 94.74 %
#
# Accuracy on Testing:
# 79.13 %
#
# Time taken to build the model is 2.81 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest160
# [[1139  172]
#  [ 376  919]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81      1311
#            1       0.84      0.71      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.13 %
#
# Accuracy on Testing:
# 78.97 %
#
# Time taken to build the model is 57.04 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest170
# [[1133  178]
#  [ 361  934]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.11 %
#
# Accuracy on Testing:
# 79.32 %
#
# Time taken to build the model is 3.15 Seconds
#
# Time taken for prediction is 0.06 Seconds
#
# -----------------
# Model: Random Forest180
# [[1145  166]
#  [ 366  929]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.79      2606
# weighted avg       0.80      0.80      0.79      2606
#
#
# Accuracy on Training:
# 94.93 %
#
# Accuracy on Testing:
# 79.59 %
#
# Time taken to build the model is 3.31 Seconds
#
# Time taken for prediction is 0.06 Seconds
#
# -----------------
# Model: Random Forest190
# [[1142  169]
#  [ 369  926]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 94.98 %
#
# Accuracy on Testing:
# 79.36 %
#
# Time taken to build the model is 3.53 Seconds
#
# Time taken for prediction is 0.06 Seconds
#
# -----------------
# Model: Random Forest200
# [[1136  175]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.11 %
#
# Accuracy on Testing:
# 79.39 %
#
# Time taken to build the model is 3.77 Seconds
#
# Time taken for prediction is 0.07 Seconds
#
# -----------------
# Model: Random Forest210
# [[1139  172]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.80      0.79      2606
#
#
# Accuracy on Training:
# 95.29 %
#
# Accuracy on Testing:
# 79.51 %
#
# Time taken to build the model is 3.95 Seconds
#
# Time taken for prediction is 0.07 Seconds
#
# -----------------
# Model: Random Forest220
# [[1130  181]
#  [ 365  930]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.06 %
#
# Accuracy on Testing:
# 79.05 %
#
# Time taken to build the model is 4.11 Seconds
#
# Time taken for prediction is 0.07 Seconds
#
# -----------------
# Model: Random Forest230
# [[1143  168]
#  [ 369  926]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.05 %
#
# Accuracy on Testing:
# 79.39 %
#
# Time taken to build the model is 4.34 Seconds
#
# Time taken for prediction is 0.09 Seconds
#
# -----------------
# Model: Random Forest240
# [[1126  185]
#  [ 359  936]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.83      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 94.98 %
#
# Accuracy on Testing:
# 79.13 %
#
# Time taken to build the model is 4.75 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest250
# [[1142  169]
#  [ 375  920]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81      1311
#            1       0.84      0.71      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.36 %
#
# Accuracy on Testing:
# 79.13 %
#
# Time taken to build the model is 5.00 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest260
# [[1135  176]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.16 %
#
# Accuracy on Testing:
# 79.36 %
#
# Time taken to build the model is 5.35 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest270
# [[1142  169]
#  [ 364  931]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.79      2606
# weighted avg       0.80      0.80      0.79      2606
#
#
# Accuracy on Training:
# 95.15 %
#
# Accuracy on Testing:
# 79.55 %
#
# Time taken to build the model is 5.18 Seconds
#
# Time taken for prediction is 0.09 Seconds
#
# -----------------
# Model: Random Forest280
# [[1141  170]
#  [ 360  935]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.80      2606
# weighted avg       0.80      0.80      0.80      2606
#
#
# Accuracy on Training:
# 95.43 %
#
# Accuracy on Testing:
# 79.66 %
#
# Time taken to build the model is 5.15 Seconds
#
# Time taken for prediction is 0.09 Seconds
#
# -----------------
# Model: Random Forest290
# [[1127  184]
#  [ 359  936]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.03 %
#
# Accuracy on Testing:
# 79.16 %
#
# Time taken to build the model is 54.66 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest300
# [[1136  175]
#  [ 366  929]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.03 %
#
# Accuracy on Testing:
# 79.24 %
#
# Time taken to build the model is 5.52 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest310
# [[1131  180]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 94.87 %
#
# Accuracy on Testing:
# 79.20 %
#
# Time taken to build the model is 5.67 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest320
# [[1134  177]
#  [ 361  934]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.10 %
#
# Accuracy on Testing:
# 79.36 %
#
# Time taken to build the model is 5.82 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Random Forest330
# [[1148  163]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.81      0.80      0.80      2606
# weighted avg       0.81      0.80      0.80      2606
#
#
# Accuracy on Training:
# 95.34 %
#
# Accuracy on Testing:
# 79.85 %
#
# Time taken to build the model is 5.98 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest340
# [[1133  178]
#  [ 361  934]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.20 %
#
# Accuracy on Testing:
# 79.32 %
#
# Time taken to build the model is 6.19 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Random Forest350
# [[1140  171]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.49 %
#
# Accuracy on Testing:
# 79.32 %
#
# Time taken to build the model is 6.33 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest360
# [[1137  174]
#  [ 368  927]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.13 %
#
# Accuracy on Testing:
# 79.20 %
#
# Time taken to build the model is 6.46 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest370
# [[1128  183]
#  [ 364  931]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.80      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.05 %
#
# Accuracy on Testing:
# 79.01 %
#
# Time taken to build the model is 6.69 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest380
# [[1132  179]
#  [ 366  929]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81      1311
#            1       0.84      0.72      0.77      1295
#
#     accuracy                           0.79      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.79      0.79      2606
#
#
# Accuracy on Training:
# 95.21 %
#
# Accuracy on Testing:
# 79.09 %
#
# Time taken to build the model is 6.82 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest390
# [[1140  171]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.85      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.80      0.79      2606
# weighted avg       0.80      0.80      0.79      2606
#
#
# Accuracy on Training:
# 95.11 %
#
# Accuracy on Testing:
# 79.55 %
#
# Time taken to build the model is 53.00 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# -----------------
# Model: Random Forest400
# [[1139  172]
#  [ 362  933]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1311
#            1       0.84      0.72      0.78      1295
#
#     accuracy                           0.80      2606
#    macro avg       0.80      0.79      0.79      2606
# weighted avg       0.80      0.80      0.79      2606
#
#
# Accuracy on Training:
# 95.10 %
#
# Accuracy on Testing:
# 79.51 %
#
# Time taken to build the model is 7.34 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# ...........Results for TFIDF Vectorizer..........
#
# -----------------
# Model: Random Forest100
# [[1164  147]
#  [ 350  945]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82      1311
#            1       0.87      0.73      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.90 %
#
# Accuracy on Testing:
# 80.93 %
#
# Time taken to build the model is 1.64 Seconds
#
# Time taken for prediction is 0.04 Seconds
#
# -----------------
# Model: Random Forest110
# [[1180  131]
#  [ 347  948]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.72 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 1.81 Seconds
#
# Time taken for prediction is 0.04 Seconds
#
# -----------------
# Model: Random Forest120
# [[1171  140]
#  [ 347  948]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.79 %
#
# Accuracy on Testing:
# 81.31 %
#
# Time taken to build the model is 1.97 Seconds
#
# Time taken for prediction is 0.04 Seconds
#
# -----------------
# Model: Random Forest130
# [[1176  135]
#  [ 343  952]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.82      0.82      2606
# weighted avg       0.82      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.76 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 2.18 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest140
# [[1161  150]
#  [ 341  954]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.86      0.74      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.13 %
#
# Accuracy on Testing:
# 81.16 %
#
# Time taken to build the model is 2.32 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest150
# [[1172  139]
#  [ 354  941]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 95.84 %
#
# Accuracy on Testing:
# 81.08 %
#
# Time taken to build the model is 2.52 Seconds
#
# Time taken for prediction is 0.05 Seconds
#
# -----------------
# Model: Random Forest160
# [[1182  129]
#  [ 349  946]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 96.02 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 2.78 Seconds
#
# Time taken for prediction is 0.06 Seconds
#
# -----------------
# Model: Random Forest170
# [[1180  131]
#  [ 349  946]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.97 %
#
# Accuracy on Testing:
# 81.58 %
#
# Time taken to build the model is 3.03 Seconds
#
# Time taken for prediction is 0.06 Seconds
#
# -----------------
# Model: Random Forest180
# [[1174  137]
#  [ 348  947]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.87      0.73      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.02 %
#
# Accuracy on Testing:
# 81.39 %
#
# Time taken to build the model is 3.37 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest190
# [[1173  138]
#  [ 348  947]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.08 %
#
# Accuracy on Testing:
# 81.35 %
#
# Time taken to build the model is 3.63 Seconds
#
# Time taken for prediction is 0.07 Seconds
#
# -----------------
# Model: Random Forest200
# [[1179  132]
#  [ 347  948]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.97 %
#
# Accuracy on Testing:
# 81.62 %
#
# Time taken to build the model is 3.44 Seconds
#
# Time taken for prediction is 0.07 Seconds
#
# -----------------
# Model: Random Forest210
# [[1177  134]
#  [ 343  952]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.99 %
#
# Accuracy on Testing:
# 81.70 %
#
# Time taken to build the model is 3.56 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest220
# [[1169  142]
#  [ 344  951]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.08 %
#
# Accuracy on Testing:
# 81.35 %
#
# Time taken to build the model is 56.25 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest230
# [[1176  135]
#  [ 347  948]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 96.18 %
#
# Accuracy on Testing:
# 81.50 %
#
# Time taken to build the model is 3.88 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest240
# [[1181  130]
#  [ 349  946]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.81      2606
# weighted avg       0.83      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.94 %
#
# Accuracy on Testing:
# 81.62 %
#
# Time taken to build the model is 4.05 Seconds
#
# Time taken for prediction is 0.08 Seconds
#
# -----------------
# Model: Random Forest250
# [[1171  140]
#  [ 357  938]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82      1311
#            1       0.87      0.72      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.12 %
#
# Accuracy on Testing:
# 80.93 %
#
# Time taken to build the model is 4.35 Seconds
#
# Time taken for prediction is 0.09 Seconds
#
# -----------------
# Model: Random Forest260
# [[1176  135]
#  [ 347  948]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 96.07 %
#
# Accuracy on Testing:
# 81.50 %
#
# Time taken to build the model is 4.37 Seconds
#
# Time taken for prediction is 0.09 Seconds
#
# -----------------
# Model: Random Forest270
# [[1173  138]
#  [ 342  953]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.82      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 95.94 %
#
# Accuracy on Testing:
# 81.58 %
#
# Time taken to build the model is 4.62 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest280
# [[1181  130]
#  [ 346  949]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 96.10 %
#
# Accuracy on Testing:
# 81.73 %
#
# Time taken to build the model is 4.74 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest290
# [[1178  133]
#  [ 352  943]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.08 %
#
# Accuracy on Testing:
# 81.39 %
#
# Time taken to build the model is 4.89 Seconds
#
# Time taken for prediction is 0.10 Seconds
#
# -----------------
# Model: Random Forest300
# [[1173  138]
#  [ 342  953]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.82      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 96.15 %
#
# Accuracy on Testing:
# 81.58 %
#
# Time taken to build the model is 5.10 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Random Forest310
# [[1173  138]
#  [ 340  955]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83      1311
#            1       0.87      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.82      0.82      2606
# weighted avg       0.82      0.82      0.82      2606
#
#
# Accuracy on Training:
# 96.15 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 5.87 Seconds
#
# Time taken for prediction is 0.11 Seconds
#
# -----------------
# Model: Random Forest320
# [[1168  143]
#  [ 348  947]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.30 %
#
# Accuracy on Testing:
# 81.16 %
#
# Time taken to build the model is 5.38 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest330
# [[1166  145]
#  [ 348  947]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.31 %
#
# Accuracy on Testing:
# 81.08 %
#
# Time taken to build the model is 5.67 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest340
# [[1172  139]
#  [ 353  942]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83      1311
#            1       0.87      0.73      0.79      1295
#
#     accuracy                           0.81      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.81      0.81      2606
#
#
# Accuracy on Training:
# 96.12 %
#
# Accuracy on Testing:
# 81.12 %
#
# Time taken to build the model is 54.25 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest350
# [[1186  125]
#  [ 350  945]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.87 %
#
# Accuracy on Testing:
# 81.77 %
#
# Time taken to build the model is 6.02 Seconds
#
# Time taken for prediction is 0.12 Seconds
#
# -----------------
# Model: Random Forest360
# [[1180  131]
#  [ 351  944]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.81      0.81      2606
# weighted avg       0.82      0.82      0.81      2606
#
#
# Accuracy on Training:
# 96.17 %
#
# Accuracy on Testing:
# 81.50 %
#
# Time taken to build the model is 6.16 Seconds
#
# Time taken for prediction is 0.13 Seconds
#
# -----------------
# Model: Random Forest370
# [[1182  129]
#  [ 343  952]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83      1311
#            1       0.88      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 96.05 %
#
# Accuracy on Testing:
# 81.89 %
#
# Time taken to build the model is 6.34 Seconds
#
# Time taken for prediction is 0.13 Seconds
#
# -----------------
# Model: Random Forest380
# [[1181  130]
#  [ 344  951]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 96.05 %
#
# Accuracy on Testing:
# 81.81 %
#
# Time taken to build the model is 6.47 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# -----------------
# Model: Random Forest390
# [[1176  135]
#  [ 343  952]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.74      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.82      0.82      0.82      2606
# weighted avg       0.82      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.97 %
#
# Accuracy on Testing:
# 81.66 %
#
# Time taken to build the model is 6.60 Seconds
#
# Time taken for prediction is 0.14 Seconds
#
# -----------------
# Model: Random Forest400
# [[1184  127]
#  [ 349  946]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1311
#            1       0.88      0.73      0.80      1295
#
#     accuracy                           0.82      2606
#    macro avg       0.83      0.82      0.82      2606
# weighted avg       0.83      0.82      0.82      2606
#
#
# Accuracy on Training:
# 95.94 %
#
# Accuracy on Testing:
# 81.73 %
#
# Time taken to build the model is 7.53 Seconds
#
# Time taken for prediction is 0.18 Seconds
